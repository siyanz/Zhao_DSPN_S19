# %% [markdown]
# # Homework 3:

# %% [markdown]
# ### **Conceptual:** Short answer questions. Be concise

# %% [markdown]
# ---
#
# 1. Using the mean squared error (MSE) as your objective function allows for a closed form solution to finding the maximum likelihood estimate (MLE) of your model parameters in linear regression. Let’s consider the simple, single predictor variable model $Y= \beta_0 + \beta_1 X $.
#
# a) Use algebra to show how you can expand out the MSE to get from i to ii below. Do your proof using Latex equation formatting.

# %% [markdown]
#  _i)_ $MSE(\beta_0, \beta_1)=E[ (Y-(\beta_0 + \beta_1 X))^2]$

# %% [markdown]
# _ii)_ $=E[Y^2] -2 \beta_0E[Y]-2 \beta_1 Cov[X,Y]-2 \beta_1 E[X]E[Y]+ \beta_0^2 +2 \beta_0 \beta_1 E[X]+\beta_1^2 Var[X]+ \beta_1^2 (E[X])^2$

# %% [markdown]
# **Answer:**

# %% [markdown]
# $MSE(\beta_0, \beta_1)= \\
# E[(Y-(\beta_0 + \beta_1 X))^2] = \\
# E[(Y^2+(\beta_0 + \beta_1 X)^2-2Y(\beta_0+\beta_1X)] = \\
# E[Y^2+\beta_0^2+\beta_1^2X^2+2\beta_0\beta_1X-2Y\beta_0-2\beta_1XY]=\\
# E[Y^2]+E[\beta_0^2]+E[\beta_1^2X^2]+E[2\beta_0\beta_1X]-E[2Y\beta_0]-E[2\beta_1XY]=\\
# E[Y^2]-2\beta_0E[Y]-2\beta_1E[XY]+\beta_0^2+2\beta_0\beta_1E[X]+\beta_1^2E[X^2]=\\
# E[Y^2]-2\beta_0E[Y]-2\beta_1(Cov[X,Y]+E[X]E[Y])+\beta_0^2+2\beta_0\beta_1E[X]+\beta_1^2(Var[X]+E[X]^2)=\\
# E[Y^2]-2\beta_0E[Y]-2\beta_1Cov[X,Y]-2\beta_1E[X]E[Y]+\beta_0^2+2\beta_0\beta_1E[X]+\beta_1^2Var[X]+\beta_1^2(E[X])^2\\
# $

# %% [markdown]
# b) Prove that the MLE of $\beta_0$ is $E[Y]- \beta_1 E[X]$ by taking the derivative of _ii_ above, with respect to $\beta_0$, setting the derivative to zero, and solving for $\beta_0$.

# %% [markdown]
# **Answer:**

# %% [markdown]
# $
# \frac{\partial MSE(\beta_0, \beta_1)}{\partial \beta_0}=
# -2E[Y]+2\beta_0+2\beta_1E[X]=0\\
# \implies 2\beta_0=2E[Y]-2\beta_1E[X]\\
# \implies \beta_0=E[Y]-\beta_1E[X]
# $

# %% [markdown]
# c) Prove that the MLE for $\beta_1$ is $Cov[X,Y]/Var[X]$ by taking the derivative of _ii_ above, with respect to $\beta_1$, setting the derivative to zero, and solving for $\beta_1$.

# %% [markdown]
# **Answer:**

# %% [markdown]
# $
# \frac{\partial MSE(\beta_0, \beta_1)}{\partial \beta_1}=\\
# -2Cov[X,Y]-2E[X]E[Y]+2\beta_0E[X]+2\beta_1Var[X]+2\beta_1(E[X])^2=\\
# -2Cov[X,Y]-2\bar{X}\bar{Y}+2\beta_0\bar{X}+2\beta_1Var[X]+2\beta_1\bar{X}^2=0\\
# \implies -2Cov[X,Y]+2\beta_1Var[X]-2\bar{X}(\bar{Y}-\beta_1\bar{X})+2\beta_0\bar{X}=\\
# -2Cov[X,Y]+2\beta_1Var[X]-2\beta_0\bar{X}+2\beta_0\bar{X}=0\\
# \implies \beta_1Var[X]=Cov[X,Y]\\
# \implies \beta_1=\frac{Cov[X,Y]}{Var[X]}
# $

# %% [markdown]
# ---
#
# 2. Using the MLE solutions shown in 1(b) and 1(c) above, show how, in the case of simple linear regression, the least squares line always passes through the point $(E(X), E(Y))$ or $(x,y)$). What does this imply about the leverage that the response and predictor variable means have on the ordinary least squares solution?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Using the $\beta_0$ value above:
#
# $y=\beta_0+\beta_1X$
#
# $\implies y=E[Y]-\beta_1E[X]+\beta_1X$
#
# When $X=E[X]$, $y=E[Y]-\beta_1E[X]+\beta_1E[X]=E[Y]$
#
# $\therefore$ the least square line always passes through $(E[X],E[Y])$.

# %% [markdown]
# Since the least square line always passes through $(\bar{X},\bar{Y})$, this point, i.e., the response and predictor means, has high leverate on the ordinary least squares solution.

# %% [markdown]
# ---
# 3. In the case where X and Y are standard normal variables (i.e. $N(0,1)$), show that the ordinary least squares solution converges to the same solution as the Pearson correlation coefficient $r=Cov[X,Y]/(\sigma_X * \sigma_Y)$. What exactly do they both converge to?

# %% [markdown]
# **Answer:**

# %% [markdown]
# $r=\frac{Cov[X,Y]}{(\sigma_X * \sigma_Y)}$
#
# When X, Y are standard normal variables, $\sigma_X=1, \sigma_Y=1$ and $r$ becomes $Cov[S,Y]$.
#
# With ordinary least squares solution, $\beta_1=\frac{Cov[X,Y]}{Var[X]}$. Since $X\sim N(0, 1)$, $Var[X]=1$.
#
# $\therefore \beta_1=Cov[X,Y]=r$

# %% [markdown]
# ---
#
# 4. Three methods for evaluating a regression model’s performance are $r^2$, $RSE$, and the $F$ Test. Show the functional form of each method and describe conceptually what it is telling you about your model.

# %% [markdown]
# **Answer:**

# %% [markdown]
# $
# r^2=\frac{TSS-RSS}{TSS}=1-\frac{RSS}{TSS}=1-\frac{\sum (y-\hat{y})^2}{\sum (y-\bar{y})^2}
# $
#
# $r^2$ is the ratio of variance explained.
#
# $
# RSE=\sqrt{\frac{RSS}{n-2}}=\sqrt{\frac{\sum (y-\hat{y})^2}{n-2}}
# $
#
# RSE is the variance of the residuals, i.e., how confident we are in the residual.
#
# $
# F=\frac{\frac{1}{p}(TSS-RSS)}{\frac{1}{n-p-1}RSS}
# $
#
# F test shows if the predicted y is better than just using the mean of y as the prediction.

# %% [markdown]
# ---
# 5. Suppose that we have a dataset with five predictors, $X_1 = GPA$, $X_2 = IQ$, $X_3 = Gender$ (1 for Female and 0 for Male), $X_4$ = Interaction between GPA and IQ, and $X_5$ = Interaction between GPA and Gender. The response variable ($Y$) is starting salary after graduation (in thousands of dollars). Suppose we use least squares to fit the model, and get $\hat{\beta_0}$ =50, $\hat{\beta_1}$ =20, $\hat{\beta_2}$ =0.07, $\hat{\beta_3}$ =35, $\hat{\beta_4}$ =0.01, $\hat{\beta_5}$ =-10.

# %% [markdown]
# a) Which answer is correct, and why?
#
# i. For a fixed value of IQ and GPA, males earn more on average than females.
#
# ii. For a fixed value of IQ and GPA, females earn more on average than males.
#
# iii. For a fixed value of IQ and GPA, males earn more on average than females provided that the GPA is high enough.
#
# iv. For a fixed value of IQ and GPA, females earn more on average than males provided that the GPA is high enough.

# %% [markdown]
# **Answer:**

# %% [markdown]
# iii. Since there is an interaction between GPA and Gender with a negative coefficient value, when GPA is high enough, males earn more money on average than females.

# %% [markdown]
# (b) Predict the salary of a female graduate with IQ of 110 and a GPA of 4.0.

# %% [markdown]
# **Answer:**

# %% [markdown]
# $20\times 4+0.07\times 110+35+0.01\times 110 \times 4-10\times 4\times 1=87.1$

# %% [markdown]
# (c) True or false: Since the coefficient for the GPA/IQ interaction term is very small, there is very little evidence of an interaction effect. Justify your answer.

# %% [markdown]
# **Answer:**

# %% [markdown]
# FALSE, the small coefficient means that the interaction has a small effect on salary.

# %% [markdown]
# ---
# 6. What are high leverage observations? How do they impact your model fits? What assumption of linear regression do they violate?

# %% [markdown]
# **Answer:**

# %% [markdown]
# High leverage observations have "extreme" predictor x values. High leverage observations pulls the regression line through it, even though it may not fit the body of the data. It violate assumption of normality.

# %% [markdown]
# ---
# 7. A linear mixed effect model has the form $Y = X\beta + Z\upsilon + \epsilon$.

# %% [markdown]
# a) What are the assumptions about $Z$ and $\upsilon$ that make this different from using a regular control variable in a simple linear regression model?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Level assignment for $Z$ is meaningless. $Z$'s variance is not accounted for in $X$.

# %% [markdown]
# b) What is the objective function for this model (i.e., the function that needs to be minimized to find the optimal parameters) and how is it different than the objective function for the ordinary least squares model?

# %% [markdown]
# **Answer:**

# %% [markdown]
# The objective function is $min(||Y-X\beta-Z\Lambda_{\theta}\upsilon||^2+||\upsilon||^2)$.
#
# It accounts for variance in $Z$ and a panelty for including a random effect factor.

# %% [markdown]
# c) What advantage does including a random effects term in your model give you with regards to understanding the fixed effects relationship?

# %% [markdown]
# **Answer:**

# %% [markdown]
# It separates effect of other uncontrolled factors from the main effect.

# %% [markdown]
# ---
#
# ### **Applied:** Show your code & plots
#
# (Include conceptual answers to questions as comments in code cells)

# %% [markdown]
# ---
# 8. Load the cbpp dataset from the lme4 library. Run ?cbpp after loading the lme4 library to get information on the dataset.
#
# (a) Plot the relationship between herd size and CBPP incidence

# %% [markdown]
# **Answer:**

# %%
# -------------------------------
# Question 8
# -------------------------------
library(lme4)
data(cbpp)
options(repr.plot.width=2.5, repr.plot.height=2) 
library("ggplot2")#load the library

######## (a) #########
ggplot(cbpp, aes(x=size, y=incidence)) + 
    geom_point(size=0.5) +
    geom_jitter()
######################
# Out:
# Loading required package: Matrix
# plot without title

# %% [markdown]
# (b) Use the lm function to model the effect of herd size (predictor) on CBPP incidence (response). How does herd size impact disease rate? Report the results of the model.

# %% [markdown]
# **Answer:**

# %%
######## (b) #########
fixed <- lm(incidence ~ size, cbpp)
fixed
######################
# Out:
# Call:
# lm(formula = incidence ~ size, data = cbpp)
#
# Coefficients:
# (Intercept)         size
#     -0.3111       0.1383

# %% [markdown]
# (c) Use the lmer function to include the herd identifier as a random effect. How does this impact the fixed effect of herd size on CBPP incidence?

# %% [markdown]
# **Answer:**

# %%
######## (c) #########
rand <- lmer(incidence ~ size + (1|herd), cbpp)
rand

# Herd size is positively associated with CBPP incidence. 
# That is as the herd size increases, so does the CBPP incidence
# After accounting for the random effects, the coefficient for the fixed effect increases. 
######################
# Out:
# Linear mixed model fit by REML ['lmerMod']
# Formula: incidence ~ size + (1 | herd)
#    Data: cbpp
# REML criterion at convergence: 257.8909
# Random effects:
#  Groups   Name        Std.Dev.
#  herd     (Intercept) 1.683
#  Residual             2.015
# Number of obs: 56, groups:  herd, 15
# Fixed Effects:
# (Intercept)         size
#     -1.6967       0.2375

# %% [markdown]
# (d) Compare the simple linear model (i.e., the fixed effects only model) with the mixed effect model using AIC (https://en.wikipedia.org/wiki/Akaike_information_criterion). Does adding the random effect to the model improve or change the fixed effect?

# %% [markdown]
# **Answer:**

# %%
######## (d) #########
ic = AIC(fixed, rand)
ic
diff(ic$AIC)

# The difference in AIC between the two models are really small. 
# Therefore, adding the random effect does not improve the fixed effect.
######################
# Out:
#       df AIC
# fixed 3  262.4036
# rand  4  265.8909
# [1] 3.487294

# %% [markdown]
# ---
#
#
# 9. This question involves the use of multiple linear regression on the _Auto_ data set. (From ISLR Chapter 3, Exercise #9)
#
# (a) Produce a scatterplot matrix which includes all of the variables in the data set.

# %% [markdown]
# **Answer:**

# %%
# -------------------------------
# Question 9
# -------------------------------
Auto <- read.table("Auto.data", header=TRUE)
Auto$horsepower <- as.numeric(Auto$horsepower)

######## (a) #########
options(repr.plot.width=5, repr.plot.height=5) 
pairs(~mpg+cylinders+displacement+horsepower+weight+acceleration+year+origin,data=Auto,
   main="Simple Scatterplot Matrix")
######################
# Out:
# plot without title

# %% [markdown]
# (b) Compute the matrix of correlations between the variables using the function _cor()_. You will need to exclude the name variable, which is qualitative.

# %% [markdown]
# **Answer:**

# %%
######## (b) #########
Auto_noname <- Auto[,-9]
Auto_noname$horsepower = as.numeric(Auto_noname$horsepower)
Auto_noname$origin = as.numeric(Auto_noname$origin)
cor(Auto_noname, use="pairwise.complete.obs")
######################
# Out:
#              mpg        cylinders  displacement horsepower weight
# mpg           1.0000000 -0.7762599 -0.8044430    0.4228227 -0.8317389
# cylinders    -0.7762599  1.0000000  0.9509199   -0.5466585  0.8970169
# displacement -0.8044430  0.9509199  1.0000000   -0.4820705  0.9331044
# horsepower    0.4228227 -0.5466585 -0.4820705    1.0000000 -0.4821507
# weight       -0.8317389  0.8970169  0.9331044   -0.4821507  1.0000000
# acceleration  0.4222974 -0.5040606 -0.5441618    0.2662877 -0.4195023
# year          0.5814695 -0.3467172 -0.3698041    0.1274167 -0.3079004
# origin        0.5636979 -0.5649716 -0.6106643    0.2973734 -0.5812652
#              acceleration year       origin
# mpg           0.4222974    0.5814695  0.5636979
# cylinders    -0.5040606   -0.3467172 -0.5649716
# displacement -0.5441618   -0.3698041 -0.6106643
# horsepower    0.2662877    0.1274167  0.2973734
# weight       -0.4195023   -0.3079004 -0.5812652
# acceleration  1.0000000    0.2829009  0.2100836
# ...

# %% [markdown]
# (c) Use the _lm()_ function to perform a multiple linear regression with mpg as the response and all other variables except name as the predictors. Use the _summary()_ function to print the results. Comment on the output. For instance:
#
# i. Is there a relationship between the predictors and the response?
#
# ii. Which predictors appear to have a statistically significant relationship to the response?
#
# iii. What does the coefficient for the year variable suggest?

# %% [markdown]
# **Answer:**

# %%
######## (c) #########
options(scipen=999)
lm_results <- lm(mpg ~ cylinders+displacement+horsepower+weight+acceleration+year+origin, Auto)
summary(lm_results)

# There are relationships between the predictors and responses.
# Among the relationships, those between mpg and displacement, weight, acceleration, year, and origin are significant.
# The co-efficient for year suggests that the years a car has is positively associated with mpg.
# Specifically, an increase in one year is associated with 0.77 increase in mpg.

######################
# Out:
# Call:
# lm(formula = mpg ~ cylinders + displacement + horsepower + weight +
#     acceleration + year + origin, data = Auto)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.629 -2.034 -0.046  1.801 13.010
#
# Coefficients:
#                 Estimate  Std. Error t value             Pr(>|t|)
# (Intercept)  -21.2844029   4.2587767  -4.998          0.000000878 ***
# cylinders     -0.2926536   0.3381909  -0.865               0.3874
# displacement   0.0160340   0.0072840   2.201               0.0283 *
# horsepower     0.0079423   0.0068094   1.166               0.2442
# weight        -0.0068702   0.0005799 -11.846 < 0.0000000000000002 ***
# acceleration   0.1539134   0.0775014   1.986               0.0477 *
# year           0.7734417   0.0493868  15.661 < 0.0000000000000002 ***
# origin         1.3464370   0.2690730   5.004          0.000000852 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 3.331 on 389 degrees of freedom
# ...

# %% [markdown]
# (d) Use the _plot()_ function to produce diagnostic plots of the linear regression fit. Comment on any problems you see with the fit. Do the residual plots suggest any unusually large outliers? Does the leverage plot identify any observations with unusually high leverage?

# %% [markdown]
# **Answer:**

# %%
######## (d) #########
library(ggfortify)
#Do the residual plots suggest any unusually large outliers? 
#Does the leverage plot identify any observations with unusually high leverage?

autoplot(lm_results, label.size = 3)

# The Normal Q-Q plot shows a few outliers. 
# The residuals vs fitted plot shows that the fitted line is not straight at the 0 mark. 
# This suggests that the model may not be accounting some higher dimension relationship between x and y
# The Residuals vs Leverage plot shows one high leverage point (#14)
######################
# Out:
# plot without title

# %% [markdown]
# (e) Use the _*_ and _:_ symbols to fit linear regression models with interaction effects. Do any interactions appear to be statistically significant?

# %% [markdown]
# **Answer:**

# %%
######## (e) #########
lm_interactions_results <- lm(mpg ~ (cylinders+displacement+horsepower+weight+acceleration+year+origin)^2, Auto)
summary(lm_interactions_results)
autoplot(lm_interactions_results)
# Interaction between displacement&weight, acceleration:year, acceleration:origin are 
######################
# Out:
# Call:
# lm(formula = mpg ~ (cylinders + displacement + horsepower + weight +
#     acceleration + year + origin)^2, data = Auto)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -8.262 -1.554  0.073  1.306 12.360
#
# Coefficients:
#                                Estimate    Std. Error t value    Pr(>|t|)
# (Intercept)                75.627534485  44.214054280   1.710    0.088019 .
# cylinders                   9.270940547   7.735988867   1.198    0.231526
# displacement               -0.339196464   0.171014140  -1.983    0.048061 *
# horsepower                  0.206608532   0.143304558   1.442    0.150225
# weight                      0.001692442   0.014759360   0.115    0.908770
# acceleration               -8.337575183   1.654734489  -5.039 0.000000737 ***
# year                        0.142520158   0.541302680   0.263    0.792474
# origin                    -20.243467071   6.797902053  -2.978    0.003095 **
# ...

# %% [markdown]
# (f) Try a few different transformations of the variables, such as log(X), √X, X2. Comment on your findings.

# %% [markdown]
# **Answer:**

# %%
######## (f) #########
pairs(~mpg+cylinders+log(displacement)+log(horsepower)+log(weight)+acceleration+sqrt(year)+origin,data=Auto,
   main="Transformed Scatterplot Matrix")

lm_new_results <- lm(mpg ~ cylinders+log(displacement)+log(horsepower)+log(weight)+acceleration+sqrt(year)+origin, Auto)
summary(lm_new_results)
autoplot(lm_interactions_results)
# Taking the logs of diaplacement, horsepower, and weight gives a linear relation between these variables and mpg.
# Same for the year variable after taking its square root.
# Without interaction terms, the linear model produce an unbiased (flat) residuals vs. fitted values.
# This suggests that the model is explaining the most of the reducible variance.
######################
# Out:
# Call:
# lm(formula = mpg ~ cylinders + log(displacement) + log(horsepower) +
#     log(weight) + acceleration + sqrt(year) + origin, data = Auto)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.817 -1.854 -0.022  1.611 12.761
#
# Coefficients:
#                    Estimate Std. Error t value             Pr(>|t|)
# (Intercept)        55.19926   11.67895   4.726            0.0000032 ***
# cylinders           0.46210    0.28791   1.605               0.1093
# log(displacement)  -1.33619    1.43508  -0.931               0.3524
# log(horsepower)     0.34555    0.15318   2.256               0.0246 *
# log(weight)       -18.78380    1.74047 -10.792 < 0.0000000000000002 ***
# acceleration        0.08683    0.06953   1.249               0.2125
# sqrt(year)         13.59715    0.79569  17.088 < 0.0000000000000002 ***
# origin              0.64209    0.27843   2.306               0.0216 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# ...

# %% [markdown]
# ---
#
# 10. This question should be answered using the _Carseats_ data set. (From ISLR Chapter 3, Exercise #10)
#
# (a) Fit a multiple regression model to predict Sales using Price,
# Urban, and US.

# %% [markdown]
# **Answer:**

# %%
# -------------------------------
# Question 10
# -------------------------------

rm(list=ls())
library("ISLR")

lm.fit = lm(Sales~Price+Urban+US, data=Carseats) #here we are using all individual predictors + interactions between income & advertising and price & age.
summary(lm.fit)
# Out:
# Call:
# lm(formula = Sales ~ Price + Urban + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9206 -1.6220 -0.0564  1.5786  7.0581
#
# Coefficients:
#              Estimate Std. Error t value             Pr(>|t|)
# (Intercept) 13.043469   0.651012  20.036 < 0.0000000000000002 ***
# Price       -0.054459   0.005242 -10.389 < 0.0000000000000002 ***
# UrbanYes    -0.021916   0.271650  -0.081                0.936
# USYes        1.200573   0.259042   4.635           0.00000486 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.472 on 396 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2335
# F-statistic: 41.52 on 3 and 396 DF,  p-value: < 0.00000000000000022

# %% [markdown]
# (b) Provide an interpretation of each coefficient in the model. Be
# careful—some of the variables in the model are qualitative!

# %% [markdown]
# **Answer:**

# %% [markdown]
# - Intercept: The average sales at a store in a rural store outside of US, when price is 0, is 13.04 (thousand) unit.
# - Price: With a unit increase in price, the sales drop by 0.05 unit.
# - UrbanYes: A store in urban area sells, on average, 0.02 less carseat than a store in rura area.
# - USYes: A store located in the US sells, on average, 1.20 more carseat than a store outside of US.

# %% [markdown]
# (c) Write out the model in equation form, being careful to handle the qualitative variables properly.

# %% [markdown]
# **Answer:**

# %% [markdown]
# $ Y_{sales} = \hat{\beta_0} + \hat{\beta_1}X_{price} + \hat{\beta_2}X_{urbanYES} + \hat{\beta_2}X_{usYES} + \epsilon $

# %% [markdown]
# (d) For which of the predictors can you reject the null hypothesis $H_0 : \beta_j = 0$?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Price and USYes

# %% [markdown]
# (e) On the basis of your response to the previous question, fit a smaller model that only uses the predictors for which there is evidence of association with the outcome.

# %% [markdown]
# **Answer:**

# %%
lm.fit2 = lm(Sales~Price+US, data=Carseats) #here we are using all individual predictors + interactions between income & advertising and price & age.
summary(lm.fit2)
# Out:
# Call:
# lm(formula = Sales ~ Price + US, data = Carseats)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9269 -1.6286 -0.0574  1.5766  7.0515
#
# Coefficients:
#             Estimate Std. Error t value             Pr(>|t|)
# (Intercept) 13.03079    0.63098  20.652 < 0.0000000000000002 ***
# Price       -0.05448    0.00523 -10.416 < 0.0000000000000002 ***
# USYes        1.19964    0.25846   4.641           0.00000471 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.469 on 397 degrees of freedom
# Multiple R-squared:  0.2393,	Adjusted R-squared:  0.2354
# F-statistic: 62.43 on 2 and 397 DF,  p-value: < 0.00000000000000022

# %% [markdown]
# (f) How well do the models in (a) and (e) fit the data?

# %% [markdown]
# **Answer:**

# %% [markdown]
# ### First model

# %%
options(repr.plot.width=5, repr.plot.height=4) 
autoplot(lm.fit)
# Out:
# plot without title

# %% [markdown]
# ### Second model

# %%
autoplot(lm.fit2)
# Out:
# plot without title

# %% [markdown]
# (g) Using the model from (e), obtain 95% confidence intervals for the coefficient(s).

# %% [markdown]
# **Answer:**

# %% [markdown]
# $\beta{_j} \pm 1.96 \cdot SE(\hat{\beta}_j)$
# - Intercept: $13.03079\pm 1.96\cdot 0.63098 \implies (11.794069,14.267511)$
# - Price: $-0.05448\pm 1.96\cdot 0.00523 \implies (-0.0647308,-0.0442292)$
# - USYes: $1.19964\pm 1.96\cdot 0.25846 \implies (0.693058,1.7062216)$

# %% [markdown]
# (h) Is there evidence of outliers or high leverage observations in the model from (e)?

# %% [markdown]
# **Answer:**

# %% [markdown]
# Based on the plots, there doesn't seem to be any outliers but there is one high leverage observation.

# %% [markdown]
# ---
#
# 11. In this exercise you will create some simulated data and will fit simple linear regression models to it. Make sure to use _set.seed(1)_ prior to starting part (a) to ensure consistent results. (From ISLR Chapter 3, Exercise #13)
#
# (a) Using the _rnorm()_ function, create a vector, $x$, containing 100 observations drawn from a N(0,1) distribution. This represents a feature, $X$.

# %% [markdown]
# **Answer:**

# %%
# -------------------------------
# Question 11
# -------------------------------

set.seed(1)
X=rnorm (100)

# %% [markdown]
# (b) Using the _rnorm()_ function, create a vector, eps, containing 100 observations drawn from a N(0,0.25) distribution i.e. a normal distribution with mean zero and variance 0.25.

# %% [markdown]
# **Answer:**

# %%
eps=rnorm (100,mean=0,sd=0.25)

# %% [markdown]
# (c) Using x and eps, generate a vector y according to the model
#
# $$ Y = -1 + 0.5X + \epsilon $$
#
# What is the length of the vector $y$? What are the values of $\beta_0$ and $\beta_1$ in this linear model?

# %% [markdown]
# **Answer:**

# %%
Y = -1 + 0.5 * X + eps
length(Y)

# length of Y is 100.
# Out:
# [1] 100

# %% [markdown]
# $\beta{_0} = -1$,
# $\beta{_1} = 0.5$

# %% [markdown]
# (d) Create a scatterplot displaying the relationship between $x$ and $y$. Comment on what you observe.

# %% [markdown]
# **Answer:**

# %%
options(repr.plot.width=5, repr.plot.height=4) 
plot(X, Y)

# They seem to have a positive linear relationship.
# Out:
# plot without title

# %% [markdown]
# (e) Fit a least squares linear model to predict y using x. Comment on the model obtained. How do $\hat{\beta_0}$ and $\hat{\beta_1}$ compare to $\beta_0$ and $\beta_1$?

# %% [markdown]
# **Answer:**

# %%
lm.rnorm = lm(Y ~ X)
summary(lm.rnorm)

# both beta values are close to the true values but not exactly the same.
# However, both beta values falls in the 95% interval calculated from Std Err.
# Out:
# Call:
# lm(formula = Y ~ X)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.46921 -0.15344 -0.03487  0.13485  0.58654
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept) -1.00942    0.02425  -41.63 <0.0000000000000002 ***
# X            0.49973    0.02693   18.56 <0.0000000000000002 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2407 on 98 degrees of freedom
# Multiple R-squared:  0.7784,	Adjusted R-squared:  0.7762
# F-statistic: 344.3 on 1 and 98 DF,  p-value: < 0.00000000000000022

# %% [markdown]
# (f) Display the least squares line on the scatterplot obtained in (d). Draw the population regression line on the plot, in a different color. Use the _legend()_ command to create an appropriate legend.

# %% [markdown]
# **Answer:**

# %%
plot(X, Y)

# %% [markdown]
# (g) Now fit a polynomial regression model that predicts $y$ using $x$ and $x^2$. Is there evidence that the quadratic term improves the model fit? Explain your answer.

# %% [markdown]
# **Answer:**

# %%
lm.rnormsq = lm(Y ~ X + I(X^2))
summary(lm.rnormsq)

# Judging by the R-squared value, the quadratic term does not improve by much.
# Also, the quadratic term does not have a significant association with Y.
# Out:
# Call:
# lm(formula = Y ~ X + I(X^2))
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.4913 -0.1563 -0.0322  0.1451  0.5675
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept) -0.98582    0.02941 -33.516 <0.0000000000000002 ***
# X            0.50429    0.02700  18.680 <0.0000000000000002 ***
# I(X^2)      -0.02973    0.02119  -1.403               0.164
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2395 on 97 degrees of freedom
# Multiple R-squared:  0.7828,	Adjusted R-squared:  0.7784
# F-statistic: 174.8 on 2 and 97 DF,  p-value: < 0.00000000000000022

# %% [markdown]
# (h) Repeat (a)–(f) after modifying the data generation process in such a way that there is less noise in the data. The model in (c) should remain the same. You can do this by decreasing the variance of the normal distribution used to generate the error term $\epsilon$ in (b). Describe your results.

# %% [markdown]
# **Answer:**

# %% [markdown]
# (i) Repeat (a)–(f) after modifying the data generation process in such a way that there is more noise in the data. The model in (c) should remain the same. You can do this by increasing the variance of the normal distribution used to generate the error term $\epsilon$ in (b). Describe your results.

# %% [markdown]
# **Answer:**

# %% [markdown]
# (j) What are the confidence intervals for $\beta_0$ and $\beta_1$ based on the original data set, the noisier data set, and the less noisy data set? Comment on your results.

# %% [markdown]
# **Answer:**
